# %%
! pip install -U openai-whisper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 4.9 MB/s  0:00:00eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached setuptools-82.0.0-py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached markupsafe-3.0.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.7 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.3/188.3 MB 6.5 MB/s  0:00:28m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 6.7 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 6.3 MB/s  0:00:09m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 3.3 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.1/802.1 kB 4.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 915.7/915.7 MB 4.8 MB/s  0:02:13m0:00:0100:06
# ...

# %%
! pip list
# Out:
# Package                  Version
# ------------------------ -----------
# asttokens                3.0.1
# certifi                  2026.2.25
# charset-normalizer       3.4.4
# comm                     0.2.3
# contourpy                1.3.3
# cuda-bindings            12.9.4
# cuda-pathfinder          1.4.0
# cycler                   0.12.1
# debugpy                  1.8.20
# decorator                5.2.1
# executing                2.2.1
# filelock                 3.25.0
# fonttools                4.61.1
# fsspec                   2026.2.0
# idna                     3.11
# ImageHash                4.3.2
# ImageIO                  2.37.2
# ipykernel                7.2.0
# ipython                  9.11.0
# ipython_pygments_lexers  1.1.1
# jedi                     0.19.2
# Jinja2                   3.1.6
# joblib                   1.5.3
# jupyter_client           8.8.0
# jupyter_core             5.9.1
# kiwisolver               1.4.9
# lazy_loader              0.4
# ...

# %%
! ffmpeg -version
# Out:
# ffmpeg version 7.1.3-0+deb13u1 Copyright (c) 2000-2025 the FFmpeg developers
# built with gcc 14 (Debian 14.2.0-19)
# ...

# %%
! whisper mam_instruction.mp3 --model base
# Out:
# 100%|███████████████████████████████████████| 139M/139M [00:17<00:00, 8.49MiB/s]
# /home/midori/Desktop/mini-project/.venv/lib/python3.13/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: Hindi
# [00:00.000 --> 00:13.000]  give the score based on the features, first step is how you can give the score to an image based on its feature in your life
# [00:13.000 --> 00:20.000]  give the scores to the image based on its feature
# [00:21.000 --> 00:23.000]  you can choose who you are using in your surroundings
# [00:23.000 --> 00:27.000]  give the score then you can make the grades
# [00:27.000 --> 00:32.000]  these types of visible statue
# [00:32.000 --> 00:35.000]  my model is quite easy
# [00:35.000 --> 00:37.000]  I will show any panel as shown
# ...
